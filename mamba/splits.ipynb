# %% [markdown]
# # Create Train/Val/Test Splits
#
# Use this notebook to generate `data/MMFW-UAV/splits/*.json` from a dataset directory.

# %%
import os
import sys
from pathlib import Path

REPO_ROOT = Path('..').resolve()
if str(REPO_ROOT) not in sys.path:
    sys.path.append(str(REPO_ROOT))

from scripts.prepare_data import create_splits

print('✅ Imports ready')
# Out:
# ✅ Imports ready

# %% [markdown]
# ## Configuration

# %%
data_root = REPO_ROOT / 'data' / 'MMFW-UAV' / 'raw'  # or 'sample'
output_dir = REPO_ROOT / 'data' / 'MMFW-UAV' / 'splits'
train_ratio = 0.8
val_ratio = 0.2
seed = 42

print(f'Data root: {data_root}')
print(f'Output dir: {output_dir}')
print(f'Train/Val ratios: {train_ratio}/{val_ratio}')
# Out:
# Data root: /Users/ivantyshchenko/Projects/Python/Hot-Peppers-Company-Computer-Vision/data/MMFW-UAV/raw
# Output dir: /Users/ivantyshchenko/Projects/Python/Hot-Peppers-Company-Computer-Vision/data/MMFW-UAV/splits
# Train/Val ratios: 0.8/0.2

# %% [markdown]
# ## Create Splits

# %%
splits = create_splits(
    data_root=str(data_root),
    output_dir=str(output_dir),
    train_ratio=train_ratio,
    val_ratio=val_ratio,
    seed=seed,
)

print('✅ Split summary:')
for name, split in splits.items():
    print(f"  {name}: {len(split['uav_types'])} UAV types")
# Out:
# ✅ Split summary:
#   train: 0 UAV types
#   val: 0 UAV types
#   test: 1 UAV types

# %% [markdown]
# ## Verify Files

# %%
print('Files created:')
for path in sorted(Path(output_dir).glob('*.json')):
    print(f'  {path.name}')
# Out:
# Files created:
#   test.json
#   train.json
#   val.json
